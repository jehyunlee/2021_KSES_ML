# %%
import sklearn

# %%
from sklearn import ensemble
dir(ensemble)
# Out:
# ['AdaBoostClassifier',
#  'AdaBoostRegressor',
#  'BaggingClassifier',
#  'BaggingRegressor',
#  'BaseEnsemble',
#  'ExtraTreesClassifier',
#  'ExtraTreesRegressor',
#  'GradientBoostingClassifier',
#  'GradientBoostingRegressor',
#  'IsolationForest',
#  'RandomForestClassifier',
#  'RandomForestRegressor',
#  'RandomTreesEmbedding',
#  'StackingClassifier',
#  'StackingRegressor',
#  'VotingClassifier',
#  'VotingRegressor',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_bagging',
#  '_base',
#  '_forest',
#  '_gb',
#  '_gb_losses',
#  '_gradient_boosting',
#  '_iforest',
#  '_stacking',
#  '_voting',
#  '_weight_boosting',
#  'typing']

# %%
d = {"A":11, "B":12, "C":13}
print(d)
# Out:
# {'A': 11, 'B': 12, 'C': 13}

# %%
list(d.keys())
# Out:
# ['A', 'B', 'C']

# %%
list(d.values())
# Out:
# [11, 12, 13]

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
# %matplotlib inline

X_ = np.linspace(0, 10, 200)
y_ = 0.1 * X_ + 0.2 * np.sin(X*2) + 0.4 * np.sin(X*4)

X = X_ + np.random.random(size=200)*0.2
y = y_ + np.random.random(size=200)*0.2
plt.scatter(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

rf = RandomForestRegressor()
rf.fit(X_train.reshape(-1, 1), y_train.reshape(-1, 1))

y_pred_train = rf.predict(X_train.reshape(-1, 1))
y_pred_test = rf.predict(X_test.reshape(-1, 1))
y_pred = rf.predict(X.reshape(-1, 1))

# %%
plt.plot(X, y_pred)

# %%
y_pred_train = rf.predict(X_train.reshape(-1, 1))
y_pred_test = rf.predict(X_test.reshape(-1, 1))

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, y_pred_train)
# Out:
# 0.987814159265611

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.8472161066674672

# %%
fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
axs[0].scatter(X_train, y_train, c="g", alpha=0.5, label="train")
axs[0].scatter(X_test, y_test, c="m", alpha=0.5, label="test")
axs[0].plot(X_, y_, c="orange", label="true")
axs[0].plot(X, y_pred, c="blue", label="predict")
handles, labels = axs[0].get_legend_handles_labels()
handles = list(handles)
labels = list(labels)
axs[0].legend(handles[2:] + handles[:2], labels[2:] + labels[:2])

axs[1].scatter(y_train, y_pred_train, c="g", alpha=0.5)
axs[1].scatter(y_test, y_pred_test, c="m", alpha=0.5)

axs[0].set_xlabel("X", fontsize="large", fontweight="bold", color="gray")
axs[0].set_ylabel("y", fontsize="large", fontweight="bold", color="gray")

axs[1].set_xlabel("true", fontsize="large", fontweight="bold", color="gray")
axs[1].set_ylabel("predict", fontsize="large", fontweight="bold", color="gray")

ticks = [-0.3, 0., 0.3, 0.6, 0.9, 1.2, 1.5, 1.8]
axs[1].set_xticks(ticks)
axs[1].set_xticklabels(ticks)
axs[1].set_yticks(ticks)
axs[1].set_yticklabels(ticks)
axs[1].grid()

fig.tight_layout()
fig.savefig("rf_example.png", dpi=200)

# %%
handles[2,:] + handles[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-b1faaf6dafff> in <module>
# ----> 1 handles[2,:] + handles[:1]
#
# TypeError: list indices must be integers or slices, not tuple
