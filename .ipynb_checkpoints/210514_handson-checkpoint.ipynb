# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 실습용 파일 다운로드

from urllib import request

url = "https://raw.githubusercontent.com/jehyunlee/2021_KSES_ML/main/penguins_pega.pkl"
savename = "data.pkl"

request.urlretrieve(url, savename)
# Out:
# ('data.pkl', <http.client.HTTPMessage at 0x7f25d2213410>)

# %%
# 실습용 파일 열기

df = pd.read_pickle("data.pkl")
df.head()
# Out:
#      species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0     Adelie  Torgersen            41.1           18.6              189.0
# 1  Chinstrap      Dream            46.7           17.9              195.0
# 2     Gentoo     Biscoe            45.8           14.2              219.0
# 3     Adelie      Dream            40.3           18.5              196.0
# 4     Gentoo     Biscoe            44.5           14.3              216.0
#
#    body_mass_g     sex    id
# 0       3325.0    Male  1569
# 1       3300.0  Female  1295
# 2       4700.0  Female  1445
# 3       4350.0    Male  1962
# 4       4100.0     NaN  1452

# %%
# 데이터 훑어보기 1. 전체 정보

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            709 non-null    object
#  1   island             709 non-null    object
#  2   bill_length_mm     705 non-null    float64
#  3   bill_depth_mm      705 non-null    float64
#  4   flipper_length_mm  705 non-null    float64
#  5   body_mass_g        705 non-null    float64
#  6   sex                687 non-null    object
#  7   id                 709 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 44.4+ KB

# %%
# 데이터 훑어보기 2. 데이터 값들

df.describe() # include="all"
df.describe(include="all")
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      709     709      705.000000     705.000000         705.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       310     346             NaN            NaN                NaN
# mean       NaN     NaN       42.751532      16.692170         195.537872
# std        NaN     NaN        8.576844       3.263662          33.686059
# min        NaN     NaN        3.770000       1.350000          18.800000
# 25%        NaN     NaN       38.900000      15.300000         190.000000
# 50%        NaN     NaN       43.600000      17.200000         196.000000
# 75%        NaN     NaN       48.400000      18.600000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex           id
# count    705.000000   687   709.000000
# ...

# %%
# 결측치 확인 1. 수
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        4
# bill_depth_mm         4
# flipper_length_mm     4
# body_mass_g           4
# sex                  22
# id                    0
# dtype: int64

# %%
# 결측치 확인 2. 행

df.loc[df["bill_length_mm"].isnull()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 359  Adelie  Torgersen             NaN            NaN                NaN
# 510  Gentoo     Biscoe             NaN            NaN                NaN
# 664  Gentoo     Biscoe             NaN            NaN                NaN
# 702  Adelie  Torgersen             NaN            NaN                NaN
#
#      body_mass_g  sex    id
# 359          NaN  NaN  1850
# 510          NaN  NaN  1035
# 664          NaN  NaN  1035
# 702          NaN  NaN  1850

# %%
df.loc[df["sex"].isnull()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 4    Gentoo     Biscoe            44.5           14.3              216.0
# 35   Gentoo     Biscoe            47.3           13.8              216.0
# 86   Gentoo     Biscoe            44.5           15.7              217.0
# 98   Gentoo     Biscoe            46.2           14.4              214.0
# 121  Adelie      Dream            37.5           18.9              179.0
# 130  Gentoo     Biscoe            44.5           15.7              217.0
# 138  Adelie  Torgersen            34.1           18.1              193.0
# 227  Adelie  Torgersen            37.8           17.3              180.0
# 291  Adelie      Dream            37.5           18.9              179.0
# 313  Adelie  Torgersen            42.0           20.2              190.0
# 319  Gentoo     Biscoe            47.3           13.8              216.0
# 359  Adelie  Torgersen             NaN            NaN                NaN
# ...

# %%
# 결측치 처리 1. 신체 데이터 결측 - 삭제
df.dropna(subset=["bill_length_mm"], inplace=True)
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            41.1           18.6              189.0
# 1    Chinstrap      Dream            46.7           17.9              195.0
# 2       Gentoo     Biscoe            45.8           14.2              219.0
# 3       Adelie      Dream            40.3           18.5              196.0
# 4       Gentoo     Biscoe            44.5           14.3              216.0
# ..         ...        ...             ...            ...                ...
# 704     Adelie      Dream            32.1           15.5              188.0
# 705     Gentoo     Biscoe            55.9           17.0              228.0
# 706     Adelie      Dream            41.3           20.3              194.0
# 707     Adelie     Biscoe            35.7           16.9              185.0
# 708  Chinstrap      Dream            52.7           19.8              197.0
#
#      body_mass_g     sex    id
# ...

# %%
# 결측치 처리 2. 성별 데이터 결측 - 보간
df_m = df.loc[df["sex"] == "Male"]
df_f = df.loc[df["sex"] == "Female"]
