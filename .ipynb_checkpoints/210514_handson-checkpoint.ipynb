# %% [markdown]
# # Part I : end-to-end machine learning

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(2021)
# Out:
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# 실습용 파일 다운로드

from urllib import request

url = "https://raw.githubusercontent.com/jehyunlee/2021_KSES_ML/main/penguins_kses.csv"
savename = "data.csv"

request.urlretrieve(url, savename)
# Out:
# ('data.csv', <http.client.HTTPMessage at 0x7f027d1d02d0>)

# %%
# 실습용 파일 열기

df = pd.read_csv("data.csv")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            36.2           16.1              187.0
# 1  Adelie      Dream            43.2           18.5              192.0
# 2  Gentoo     Biscoe            40.9           13.7              214.0
# 3  Adelie      Dream            42.2           18.5              180.0
# 4  Adelie      Dream            39.2           18.6              190.0
#
#    body_mass_g     sex    id
# 0       3550.0  Female  1620
# 1       4100.0    Male  1969
# 2       4650.0  Female  1565
# 3       3550.0  Female  1338
# 4       4250.0    Male  1292

# %%
# 일단 머신러닝

# %%
# target feature
y = df["body_mass_g"]

# input features
X = df.drop(["body_mass_g", "id"], axis=1)
X.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm     sex
# 0  Adelie  Torgersen            36.2           16.1              187.0  Female
# 1  Adelie      Dream            43.2           18.5              192.0    Male
# 2  Gentoo     Biscoe            40.9           13.7              214.0  Female
# 3  Adelie      Dream            42.2           18.5              180.0  Female
# 4  Adelie      Dream            39.2           18.6              190.0    Male

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2021)

# %%
# 머신러닝 모델 : RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

# 학습: 인코딩 에러 발생
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1e3f2a3b1e7d> in <module>
#       5
#       6 # 학습: 인코딩 에러 발생
# ----> 7 rf.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Chinstrap'

# %%
X_train.head()
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 527  Chinstrap      Dream            53.5           19.9              205.0
# 86      Adelie     Biscoe            35.9           19.2              189.0
# 11      Adelie  Torgersen            39.6           17.2              196.0
# 580     Adelie  Torgersen            37.2           19.4              184.0
# 416     Gentoo     Biscoe            50.1           15.0              225.0
#
#         sex
# 527    Male
# 86   Female
# 11   Female
# 580    Male
# 416    Male

# %%
# categorical features one-hot encoding
X_train = pd.get_dummies(X_train)
X_train.head()
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  species_Adelie  \
# 527            53.5           19.9              205.0               0
# 86             35.9           19.2              189.0               1
# 11             39.6           17.2              196.0               1
# 580            37.2           19.4              184.0               1
# 416            50.1           15.0              225.0               0
#
#      species_Chinstrap  species_Gentoo  island_Biscoe  island_Dream  \
# 527                  1               0              0             1
# 86                   0               0              1             0
# 11                   0               0              0             0
# 580                  0               0              0             0
# 416                  0               1              1             0
#
#      island_Torgersen  sex_Female  sex_Male
# 527                 0           0         1
# 86                  0           1         0
# 11                  1           1         0
# 580                 1           0         1
# 416                 0           0         1

# %%
# 다시 학습 : 결측치 에러 발생

rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-858f93b27b87> in <module>
#       1 # 다시 학습 : 결측치 에러 발생
#       2
# ----> 3 rf.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
# 학습데이터 X 결측치 확인

X_train.isnull().sum()
# Out:
# bill_length_mm       3
# bill_depth_mm        3
# flipper_length_mm    3
# species_Adelie       0
# species_Chinstrap    0
# species_Gentoo       0
# island_Biscoe        0
# island_Dream         0
# island_Torgersen     0
# sex_Female           0
# sex_Male             0
# dtype: int64

# %%
X_train.loc[X_train["bill_length_mm"].isnull()]
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  species_Adelie  \
# 168             NaN            NaN                NaN               1
# 512             NaN            NaN                NaN               0
# 719             NaN            NaN                NaN               0
#
#      species_Chinstrap  species_Gentoo  island_Biscoe  island_Dream  \
# 168                  0               0              0             0
# 512                  0               1              1             0
# 719                  0               1              1             0
#
#      island_Torgersen  sex_Female  sex_Male
# 168                 1           0         0
# 512                 0           0         0
# 719                 0           0         0

# %%
# 결측치 제거

X_train = X_train.dropna()
X_train.isnull().sum()
# Out:
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# species_Adelie       0
# species_Chinstrap    0
# species_Gentoo       0
# island_Biscoe        0
# island_Dream         0
# island_Torgersen     0
# sex_Female           0
# sex_Male             0
# dtype: int64

# %%
# 다시 학습 시도 : 또 결측치

rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c222799629b9> in <module>
#       1 # 다시 학습 시도 : 또 결측치
#       2
# ----> 3 rf.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
# --> 805                         ensure_2d=False, dtype=None)
#     806     else:
#     807         y = column_or_1d(y, warn=True)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# y 인자 결측치 확인

y_train.isnull().sum()
# Out:
# 3

# %%
y_train.loc[y_train.isnull()]
# Out:
# 168   NaN
# 512   NaN
# 719   NaN
# Name: body_mass_g, dtype: float64

# %%
# y 인자 결측치 제거

y_train = y_train.dropna()
y_train.isnull().sum()
# Out:
# 0

# %%
# 다시 학습

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# 예측 : 에러 - categorical feature
y_pred_test = rf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-17322a6a2f9f> in <module>
#       1 # 예측 : 에러 - categorical feature
# ----> 2 y_pred_test = rf.predict(X_test)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     781         check_is_fitted(self)
#     782         # Check data
# --> 783         X = self._validate_X_predict(X)
#     784
#     785         # Assign chunk of trees to jobs
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     386         """Validate X whenever one tries to predict, apply, predict_proba"""
#     387         if check_input:
# --> 388             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     389             if issparse(X) and (X.indices.dtype != np.intc or
#     390                                 X.indptr.dtype != np.intc):
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Adelie'

# %%
# one-hot encoding

X_test = pd.get_dummies(X_test)
X_test.head()
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  species_Adelie  \
# 232            40.6           18.8              193.0               1
# 197            51.7           20.3              194.0               0
# 74             46.5           14.5              213.0               0
# 390            52.5           15.6              221.0               0
# 269            33.1           16.1              178.0               1
#
#      species_Chinstrap  species_Gentoo  island_Biscoe  island_Dream  \
# 232                  0               0              1             0
# 197                  1               0              0             1
# 74                   0               1              1             0
# 390                  0               1              1             0
# 269                  0               0              0             1
#
#      island_Torgersen  sex_Female  sex_Male
# 232                 0           0         1
# 197                 0           0         1
# 74                  0           1         0
# 390                 0           0         1
# 269                 0           1         0

# %%
X_test = X_test.dropna()
X_test.isnull().sum()
# Out:
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# species_Adelie       0
# species_Chinstrap    0
# species_Gentoo       0
# island_Biscoe        0
# island_Dream         0
# island_Torgersen     0
# sex_Female           0
# sex_Male             0
# dtype: int64

# %%
# 머신러닝 예측 (1) 학습 데이터

y_train_pred = rf.predict(X_train)

# %%
# 예측 결과 시각화
plt.scatter(y_train, y_train_pred, alpha=0.1)

# %%
# 정확도 확인

from sklearn.metrics import r2_score

r2_train = r2_score(y_train, y_train_pred)
print(f"# R2_train = {r2_train}")
# Out:
# # R2_train = 0.6208082683750278

# %%
# 머신러닝 예측 (2) 테스트 데이터

y_test_pred = rf.predict(X_test)

# %%
# 예측 결과 시각화 : 데이터 수 불일치
plt.scatter(y_test, y_test_pred, alpha=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-01ef0c480792> in <module>
#       1 # 예측 결과 시각화 : 데이터 수 불일치
# ----> 2 plt.scatter(y_test, y_test_pred, alpha=0.1)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3039         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    3040         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# -> 3041         **({"data": data} if data is not None else {}), **kwargs)
#    3042     sci(__ret)
#    3043     return __ret
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4476         y = np.ma.ravel(y)
#    4477         if x.size != y.size:
# -> 4478             raise ValueError("x and y must be the same size")
#    4479
#    4480         if s is None:
#
# ValueError: x and y must be the same size

# %%
print(y_test.shape, y_test_pred.shape)
# Out:
# (221,) (220,)

# %%
set(y_test.index) - set(X_test.index)
# Out:
# {520}

# %%
y_test = y_test.drop(index=520)

# %%
plt.scatter(y_test, y_test_pred, alpha=0.1)

# %%
# 정확도 확인

r2_test = r2_score(y_test, y_test_pred)
print(f"# R2_test = {r2_test}")
# Out:
# # R2_test = -0.06094435937362319

# %%
# 인자 중요도

fi = rf.feature_importances_
fi
# Out:
# array([0.18535005, 0.17170982, 0.40865315, 0.00397773, 0.00514866,
#        0.13237337, 0.0163959 , 0.01091455, 0.00377726, 0.02534955,
#        0.03634994])

# %%
plt.barh(X_train.columns, fi)
# Out:
# <BarContainer object of 11 artists>

# %%
# noise 섞기

X_train["noise"] = np.random.random(size=X_train.shape[0])
X_test["noise"] = np.random.random(size=X_test.shape[0])
X_train.head()
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  species_Adelie  \
# 527            53.5           19.9              205.0               0
# 86             35.9           19.2              189.0               1
# 11             39.6           17.2              196.0               1
# 580            37.2           19.4              184.0               1
# 416            50.1           15.0              225.0               0
#
#      species_Chinstrap  species_Gentoo  island_Biscoe  island_Dream  \
# 527                  1               0              0             1
# 86                   0               0              1             0
# 11                   0               0              0             0
# 580                  0               0              0             0
# 416                  0               1              1             0
#
#      island_Torgersen  sex_Female  sex_Male     noise
# 527                 0           0         1  0.823791
# 86                  0           1         0  0.305151
# 11                  1           1         0  0.307543
# 580                 1           0         1  0.201323
# 416                 0           0         1  0.265165

# %%
# 다시 머신러닝, 정확도, 인자 중요도 확인

rf.fit(X_train, y_train)
y_train_pred = rf.predict(X_train)
r2_test_noise = r2_score(y_test, y_test_pred)
print(f"R2_test_noise = {r2_test_noise}")
# Out:
# R2_test_noise = -0.06094435937362319

# %%
fi_noise = rf.feature_importances_
plt.barh(X_train.columns, fi_noise)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# # Part II : Data Preprocessing

# %% [markdown]
# ## Overview

# %%
# 데이터 훑어보기 1. 전체 정보

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            736 non-null    object
#  1   island             736 non-null    object
#  2   bill_length_mm     732 non-null    float64
#  3   bill_depth_mm      732 non-null    float64
#  4   flipper_length_mm  732 non-null    float64
#  5   body_mass_g        732 non-null    float64
#  6   sex                714 non-null    object
#  7   id                 736 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 46.1+ KB

# %%
# 데이터 훑어보기 2. 데이터 값들

df.describe() # include="all"
df.describe(include="all")
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      736     736      732.000000     732.000000         732.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       329     359             NaN            NaN                NaN
# mean       NaN     NaN       43.850956      17.166120         200.840164
# std        NaN     NaN        5.466757       1.958167          14.065525
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.175000      15.600000         190.000000
# 50%        NaN     NaN       44.100000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex           id
# count    732.000000   714   736.000000
# unique          NaN     2          NaN
# top             NaN  Male          NaN
# freq            NaN   360          NaN
# mean    3926.500342   NaN  1485.622283
# std     1296.590258   NaN   281.845046
# min        2.850000   NaN  1004.000000
# 25%     3450.000000   NaN  1252.000000
# 50%     3950.000000   NaN  1481.500000
# 75%     4725.000000   NaN  1714.500000
# max     6300.000000   NaN  1998.000000

# %% [markdown]
# ## Cleansing

# %%
# 결측치 확인 1. 수
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        4
# bill_depth_mm         4
# flipper_length_mm     4
# body_mass_g           4
# sex                  22
# id                    0
# dtype: int64

# %%
# 결측치 확인 2. 행

df.loc[df["body_mass_g"].isnull()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 168  Adelie  Torgersen             NaN            NaN                NaN
# 512  Gentoo     Biscoe             NaN            NaN                NaN
# 520  Adelie  Torgersen             NaN            NaN                NaN
# 719  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex    id
# 168          NaN  NaN  1075
# 512          NaN  NaN  1011
# 520          NaN  NaN  1075
# 719          NaN  NaN  1011

# %%
df.loc[df["sex"].isnull()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 168  Adelie  Torgersen             NaN            NaN                NaN
# 192  Gentoo     Biscoe            47.3           13.8              216.0
# 226  Gentoo     Biscoe            44.5           15.7              217.0
# 267  Adelie      Dream            37.5           18.9              179.0
# 273  Adelie  Torgersen            34.1           18.1              193.0
# 276  Adelie  Torgersen            37.8           17.3              180.0
# 297  Adelie  Torgersen            37.8           17.3              180.0
# 341  Gentoo     Biscoe            47.3           13.8              216.0
# 369  Gentoo     Biscoe            44.5           14.3              216.0
# 376  Gentoo     Biscoe            46.2           14.4              214.0
# 391  Adelie  Torgersen            42.0           20.2              190.0
# 446  Gentoo     Biscoe            44.5           14.3              216.0
# 450  Gentoo     Biscoe            46.2           14.4              214.0
# 512  Gentoo     Biscoe             NaN            NaN                NaN
# 514  Adelie      Dream            37.5           18.9              179.0
# 520  Adelie  Torgersen             NaN            NaN                NaN
# 522  Adelie  Torgersen            37.8           17.1              186.0
# 528  Adelie  Torgersen            34.1           18.1              193.0
# 638  Adelie  Torgersen            37.8           17.1              186.0
# 661  Adelie  Torgersen            42.0           20.2              190.0
# 664  Gentoo     Biscoe            44.5           15.7              217.0
# 719  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex    id
# 168          NaN  NaN  1075
# 192       4725.0  NaN  1090
# 226       4875.0  NaN  1794
# 267       2975.0  NaN  1522
# 273       3475.0  NaN  1989
# 276       3700.0  NaN  1598
# 297       3700.0  NaN  1598
# 341       4725.0  NaN  1090
# 369       4100.0  NaN  1059
# 376       4650.0  NaN  1489
# 391       4250.0  NaN  1300
# 446       4100.0  NaN  1059
# 450       4650.0  NaN  1489
# 512          NaN  NaN  1011
# 514       2975.0  NaN  1522
# 520          NaN  NaN  1075
# 522       3300.0  NaN  1980
# 528       3475.0  NaN  1989
# 638       3300.0  NaN  1980
# 661       4250.0  NaN  1300
# 664       4875.0  NaN  1794
# 719          NaN  NaN  1011

# %%
# 결측치 처리 1. 신체 데이터 결측 - 삭제
df.dropna(subset=["sex"], axis=0, inplace=True)
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            36.2           16.1              187.0
# 1       Adelie      Dream            43.2           18.5              192.0
# 2       Gentoo     Biscoe            40.9           13.7              214.0
# 3       Adelie      Dream            42.2           18.5              180.0
# 4       Adelie      Dream            39.2           18.6              190.0
# ..         ...        ...             ...            ...                ...
# 731     Adelie      Dream            43.2           18.5              192.0
# 732     Adelie      Dream            37.5           18.5              199.0
# 733     Adelie      Dream            39.6           18.8              190.0
# 734  Chinstrap      Dream            51.3           18.2              197.0
# 735     Adelie     Biscoe            39.0           17.5              186.0
#
#      body_mass_g     sex    id
# 0         3550.0  Female  1620
# 1         4100.0    Male  1969
# 2         4650.0  Female  1565
# 3         3550.0  Female  1338
# 4         4250.0    Male  1292
# ..           ...     ...   ...
# 731       4100.0    Male  1969
# 732       4475.0    Male  1331
# 733       4600.0    Male  1151
# 734       3750.0    Male  1008
# 735       3550.0  Female  1541
#
# [714 rows x 8 columns]

# %%
# 중복값 확인
df.duplicated(["id"]).sum()
# Out:
# 381

# %%
df.loc[df.duplicated(["id"])].sort_values("id")
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 706     Gentoo     Biscoe            59.6           17.0              230.0
# 734  Chinstrap      Dream            51.3           18.2              197.0
# 362     Adelie      Dream            36.4           17.0              195.0
# 393     Adelie      Dream            36.4           17.0              195.0
# 672     Gentoo     Biscoe            42.7           13.7              208.0
# ..         ...        ...             ...            ...                ...
# 352     Adelie     Biscoe            37.8           18.3              174.0
# 682     Adelie     Biscoe            37.8           20.0              190.0
# 456     Gentoo     Biscoe            42.6           13.7              213.0
# 410     Adelie  Torgersen            39.6           17.2              196.0
# 709     Gentoo     Biscoe            48.7           14.1              210.0
#
#      body_mass_g     sex    id
# 706     6050.000    Male  1004
# 734     3750.000    Male  1008
# 362        3.325  Female  1012
# 393     3325.000  Female  1012
# 672     3950.000  Female  1019
# ..           ...     ...   ...
# 352     3400.000  Female  1979
# 682     4250.000    Male  1981
# 456     4950.000  Female  1982
# 410     3550.000  Female  1988
# 709     4450.000  Female  1998
#
# [381 rows x 8 columns]

# %%
df.query("id == 1004")
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 323  Gentoo  Biscoe            59.6           17.0              230.0
# 706  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex    id
# 323       6050.0  Male  1004
# 706       6050.0  Male  1004

# %%
# 중복값 처리
df.drop_duplicates(["id"], inplace=True)
df.shape
# Out:
# (333, 8)

# %%
# 데이터 분포 확인 1. categorical features
sns.countplot(x=df["species"], hue=df["island"])
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
# 데이터 분포 확인 2. numerical features
sns.histplot(x=df["bill_length_mm"], hue=df["island"], multiple="dodge")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.kdeplot(x=df["bill_length_mm"], hue=df["sex"], fill=True)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
# 데이터 이상치 확인

sns.pairplot(df)

# %%
df.query("body_mass_g < 2000")
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 9    Chinstrap      Dream            46.5           17.9              192.0
# 20      Adelie  Torgersen            37.7           19.8              198.0
# 26      Gentoo     Biscoe            43.5           14.2              220.0
# 56      Adelie  Torgersen            38.8           17.6              191.0
# 66      Adelie  Torgersen            34.6           17.2              189.0
# 75      Gentoo     Biscoe            50.4           15.3              224.0
# 86      Adelie     Biscoe            35.9           19.2              189.0
# 91      Gentoo     Biscoe            42.8           14.2              209.0
# 135  Chinstrap      Dream            48.5           17.5              191.0
# 136     Adelie     Biscoe            41.1           19.1              188.0
# 155     Adelie     Biscoe            45.6           20.3              191.0
# 162     Gentoo     Biscoe            48.4           14.6              213.0
# 180     Adelie      Dream            41.1           17.5              190.0
# 186     Adelie     Biscoe            39.0           17.5              186.0
# 281     Adelie     Biscoe            34.5           18.1              187.0
# 337     Adelie  Torgersen            41.5           18.3              195.0
# 431     Adelie     Biscoe            36.4           17.1              184.0
#
#      body_mass_g     sex    id
# 9          3.500  Female  1348
# 20         3.500    Male  1835
# 26         4.700  Female  1911
# 56         3.275  Female  1507
# 66         3.200  Female  1466
# 75         5.550    Male  1102
# 86         3.800  Female  1186
# 91         4.700  Female  1099
# 135        3.400    Male  1104
# 136        4.100    Male  1168
# 155        4.600    Male  1758
# 162        5.850    Male  1155
# 180        3.900    Male  1867
# 186        3.550  Female  1541
# 281        2.900  Female  1041
# 337        4.300    Male  1935
# 431        2.850  Female  1370

# %%
df.query("(bill_length_mm > 34) & (bill_length_mm < 36)")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 6    Adelie  Torgersen            35.1           19.4              193.0
# 21   Adelie      Dream            35.6           17.5              191.0
# 42   Adelie  Torgersen            34.4           18.4              184.0
# 54   Adelie      Dream            35.7           18.0              202.0
# 58   Adelie  Torgersen            35.2           15.9              186.0
# 66   Adelie  Torgersen            34.6           17.2              189.0
# 69   Adelie     Biscoe            35.0           17.9              192.0
# 86   Adelie     Biscoe            35.9           19.2              189.0
# 106  Adelie  Torgersen            35.5           17.5              190.0
# 116  Adelie     Biscoe            35.0           17.9              190.0
# 156  Adelie  Torgersen            34.6           21.1              198.0
# 167  Adelie     Biscoe            35.3           18.9              187.0
# 212  Adelie     Biscoe            35.7           16.9              185.0
# 281  Adelie     Biscoe            34.5           18.1              187.0
# 405  Adelie  Torgersen            35.7           17.0              189.0
# 455  Adelie  Torgersen            35.9           16.6              190.0
# 540  Adelie     Biscoe            35.5           16.2              195.0
#
#      body_mass_g     sex    id
# 6         4200.0    Male  1510
# 21        3175.0  Female  1322
# 42        3325.0  Female  1663
# 54        3550.0  Female  1252
# 58        3050.0  Female  1947
# 66           3.2  Female  1466
# 69        3725.0  Female  1274
# 86           3.8  Female  1186
# 106       3700.0  Female  1112
# 116       3450.0  Female  1568
# 156       4400.0    Male  1517
# 167       3800.0  Female  1946
# 212       3150.0  Female  1350
# 281          2.9  Female  1041
# 405       3350.0  Female  1211
# 455       3050.0  Female  1098
# 540       3350.0  Female  1030

# %%
sns.pairplot(df.query("body_mass_g > 2000"))

# %%
df = df.drop(index=df.query("body_mass_g < 2000").index)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# ## Data Preparation

# %%
df.shape
# Out:
# (316, 8)

# %%
X = df[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "sex", "species", "island"]]
y = df["body_mass_g"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, 
                         figsize=(6,9), constrained_layout=True)

cols = ["species", "island", "sex"]

for ax, col in zip(axes[:, 0], cols):
    order = np.sort(X[col].unique())
    sns.countplot(x=X_train[col], order=order, ax=ax)
    ax.set_facecolor("#DDFFDD")
    ax.grid(axis="y")

for ax, col in zip(axes[:, 1], cols):
    order = np.sort(X[col].unique())
    sns.countplot(x=X_test[col], order=order, ax=ax)
    ax.set_facecolor("#FFDDFF")
    ax.grid(axis="y")

axes[0, 0].set_title("trainset", fontsize=16, color="g", pad=12)
axes[0, 1].set_title("testset", fontsize=16, color="m", pad=12)
# Out:
# Text(0.5, 1.0, 'testset')

# %%
# stratified sampling

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=X[["species", "island", "sex"]])

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, 
                         figsize=(6,9), constrained_layout=True)

cols = ["species", "island", "sex"]

for ax, col in zip(axes[:, 0], cols):
    order = np.sort(X[col].unique())
    sns.countplot(x=X_train[col], order=order, ax=ax)
    ax.set_facecolor("#DDFFDD")
    ax.grid(axis="y")

for ax, col in zip(axes[:, 1], cols):
    order = np.sort(X[col].unique())
    sns.countplot(x=X_test[col], order=order, ax=ax)
    ax.set_facecolor("#FFDDFF")
    ax.grid(axis="y")
    
axes[0, 0].set_title("trainset", fontsize=16, color="g", pad=12)
axes[0, 1].set_title("testset", fontsize=16, color="m", pad=12)
# Out:
# Text(0.5, 1.0, 'testset')

# %% [markdown]
# ## Machine Learning (1) get_dummies

# %%
X_train_1 = pd.get_dummies(X_train)
X_train_1.head()
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  sex_Female  sex_Male  \
# 55             52.0           19.0              197.0           0         1
# 366            48.7           15.1              222.0           0         1
# 69             35.0           17.9              192.0           1         0
# 33             37.6           19.3              181.0           1         0
# 112            49.8           15.9              229.0           0         1
#
#      species_Adelie  species_Chinstrap  species_Gentoo  island_Biscoe  \
# 55                0                  1               0              0
# 366               0                  0               1              1
# 69                1                  0               0              1
# 33                1                  0               0              0
# 112               0                  0               1              1
#
#      island_Dream  island_Torgersen
# 55              1                 0
# 366             0                 0
# 69              0                 0
# 33              1                 0
# 112             0                 0

# %%
rf = RandomForestRegressor()
rf.fit(X_train_1, y_train)
# Out:
# RandomForestRegressor()

# %%
y_train_pred = rf.predict(X_train_1)

X_test_1 = pd.get_dummies(X_test)
y_test_pred = rf.predict(X_test_1)

# %%
print(f"# R2_train = {r2_score(y_train, y_train_pred)}")
print(f"# R2_test = {r2_score(y_test, y_test_pred)}")
# Out:
# # R2_train = 0.980770528111677
# # R2_test = 0.8432083158625221

# %%
fig, axs = plt.subplots(ncols=2)

axs[0].scatter(y_train, y_train_pred, alpha=0.1)
axs[1].scatter(y_test, y_test_pred, alpha=0.1)

# %%
fi = rf.feature_importances_
plt.barh(X_train_1.columns, fi)
# Out:
# <BarContainer object of 11 artists>

# %%
X_train_1["noise"] = np.random.random(size=X_train_1.shape[0])
X_test_1["noise"] = np.random.random(size=X_test_1.shape[0])

# %%
rf = RandomForestRegressor()
rf.fit(X_train_1, y_train)

y_train_pred = rf.predict(X_train_1)
y_test_pred = rf.predict(X_test_1)

print(f"# R2_train = {r2_score(y_train, y_train_pred)}")
print(f"# R2_test = {r2_score(y_test, y_test_pred)}")
# Out:
# # R2_train = 0.9818025223854548
# # R2_test = 0.8406094336732693

# %%
fig, axs = plt.subplots(ncols=2)

axs[0].scatter(y_train, y_train_pred, alpha=0.1)
axs[1].scatter(y_test, y_test_pred, alpha=0.1)

# %%
fi = rf.feature_importances_
plt.barh(X_train_1.columns, fi)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ## Machine Learning (2) pipeline

# %%
# encoder
from sklearn.preprocessing import OneHotEncoder

# machine learning models
from sklearn.ensemble import RandomForestRegressor

# pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# data split
from sklearn.model_selection import train_test_split

# %%
cat_features = ["species", "island", "sex"]
cat_transformer = OneHotEncoder(sparse=False)

num_features = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm"]
num_transformer = 'passthrough'

preprocessor = ColumnTransformer(transformers=[("num", num_transformer, num_features), 
                                               ("cat", cat_transformer, cat_features)])

model = Pipeline(steps=[("preprocessor", preprocessor), 
                        ("rf", RandomForestRegressor())])

# %%
from sklearn import set_config

set_config(display='diagram') 
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['bill_length_mm',
#                                                    'bill_depth_mm',
#                                                    'flipper_length_mm']),
#                                                  ('cat',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['species', 'island',
#                                                    'sex'])])),
#                 ('rf', RandomForestRegressor())])

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
print(f"# R2_train = {r2_score(y_train, y_train_pred)}")
print(f"# R2_test = {r2_score(y_test, y_test_pred)}")
# Out:
# # R2_train = 0.9811531645459588
# # R2_test = 0.8432835638372923

# %%
fig, axs = plt.subplots(ncols=2)

axs[0].scatter(y_train, y_train_pred, alpha=0.1)
axs[1].scatter(y_test, y_test_pred, alpha=0.1)

# %%
# permutation importance

from sklearn.inspection import permutation_importance

pi = permutation_importance(model, X_test, y_test, n_repeats=30, random_state=2021)

# %%
plt.barh(X_train.columns, pi.importances_mean, xerr=pi.importances_std)
# Out:
# <BarContainer object of 6 artists>
